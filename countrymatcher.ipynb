# %% [markdown]
# Uses the Google Gemini SDK to generate a dictionary matching various terms to a standardized list of countries

# %%
import google.generativeai as genai
import pandas as pd
import json

# %%
genai.configure(api_key='')

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
df = pd.read_csv('affiliations.csv')
df

# %%
f = df['Author Affiliations'].to_list()
f = list(set(f))

# %%
z = [str(item) for item in f]

# %%
prompt = " | ".join(z)
prompt

# %% [markdown]
# You may have to run this multiple times starting from where the model leaves off since sometimes the entire list passed isn't covered

# %%
response = model.generate_content(f'Create a dictionary that maps each unique value in this list to your best guess as to what country it refers to. Put Unknown for ones where you cannot decide. Map every unique value and do not miss any. Return a dictionary where the key is the phrase from the list and the value is the best guess as to what country it refers to. Use consistent names for each country. Each unique value is separated by a space, a bar and another space. Go in order of the list provided. Do not change any names that are in the list that is provided, simply match it to a country. Here is the list: {prompt}')

# %%
print(response.text)

# %%
country_dict = {
    "nan": "Unknown",
    "Lawrence Livermore National Laboratory": "United States",
    "EDS Vice President of Publications and Products": "Unknown",
    "TAIWAN": "Taiwan",
    "University of Missouri": "United States",
    "Russian Federation": "Russia",
    "South Kore": "South Korea",
    "SUPELEC-LGEP": "France",
    "CA 94025 USA.": "United States",
    "Icheon": "South Korea",
    "China,": "China",
    "KY": "United States",
    "jan_sevenhans@amis.com": "Unknown",
    "Denmark": "Denmark",
    "NY": "United States",
    "MI": "United States",
    "ID": "United States",
    "IT": "Italy",
    "Microsystems Technology Office": "Unknown",
    "San Diego": "United States",
    "Sri Lanka": "Sri Lanka",
    "Slovakia": "Slovakia",
    "Finland.": "Finland",
    "Sandia National Laboratory": "United States",
    "People's Republic of China": "China",
    "University of Applied Sciences and Arts of Southern Switzerland": "Switzerland",
    "United Kingdom.": "United Kingdom",
    "National University of Singapore": "Singapore",
    "College Park": "United States",
    "University College London": "United Kingdom",
    "Italy.": "Italy",
    "New Imaging Technologies": "Unknown",
    "Sheffield": "United Kingdom",
    "CANADA": "Canada",
    "NO": "Norway",
    "Chunghwa Telecom Company Limited": "Taiwan",
    "Princeton University": "United States",
    "Ecuador": "Ecuador",
    "Universidade Federal de Vicosa - UFV": "Brazil",
    "SEMI Advanced Semiconductor Manufacturing Conference": "Unknown",
    "Texas": "United States",
    "Slovenia": "Slovenia",
    "International College of Semiconductor Technology": "Unknown",
    "Intel Austria GmbH": "Austria",
    "Baltimore": "United States",
    "Fudan University": "China",
    "DRSEL-TL-DS": "Unknown",
    "999077": "Unknown",
    "Kharagpur": "India",
    "VT": "United States",
    "University of Oulu": "Finland",
    "RF and microwave applications": "Unknown",
    "Philippines": "Philippines",
    "South Africa E-mail: marius.goosen@up.ac.za": "South Africa",
    "Singapore University of Technology and Design": "Singapore",
    "ONT": "Canada",
    "fax: +27-21-808-4981": "South Africa",
    "Czech Republic": "Czech Republic",
    "OH": "United States",
    "SI": "Slovenia",
    "Institute of NanoEngineering and MicroSystems": "Unknown",
    "NXP Semiconductors Inc.": "Netherlands",
    "Shanghai Jiao Tong University": "China",
    "Mol Belgium": "Belgium",
    "Deutschland": "Germany",
    "Pennsylvania": "United States",
    "Uganda": "Uganda",
    "Uruguay": "Uruguay",
    "Proceedings of the IEEE": "United States",
    "3SP Technologies": "Unknown",
    "VietNam": "Vietnam",
    "KSA": "Saudi Arabia",
    "UC Berkeley": "United States",
    "Kingdom of Saudi Arabia": "Saudi Arabia",
    "Tunisie": "Tunisia",
    "UC Berkeley and LBNL": "United States",
    "The Netherlands": "Netherlands",
    "AMS AG": "Austria",
    "Alcatel-Lucent Shanghai Bell Co. Ltd": "China",
    "ARCES": "Unknown",
    "KR": "South Korea",
    "Thailand": "Thailand",
    "JDS Uniphase Corporation": "Canada",
    "MO": "United States",
    "IR": "Iran",
    "Rep. of Korea": "South Korea",
    "CRISMAT-CNRS UMR6508": "France",
    "Taipei": "Taiwan",
    "University of Texas Dallas": "United States",
    "CT": "United States",
    "South Africa.": "South Africa",
    "Bulgaria": "Bulgaria",
    "University of Michigan-Dearborn": "United States",
    "cranincj@imec.be": "Unknown",
    "AMD Research": "United States",
    "R. O. C.": "Taiwan",
    "Semiconductor Amplifier": "Unknown",
    "P.R. China": "China",
    "VA~22030": "United States",
    "NTT Electrical Communications Laboratories": "Japan",
    "AZ": "United States",
    "Berkeley": "United States",
    "EPSILON Laboratory": "Unknown",
    "Eindhoven": "Netherlands",
    "Glasgow": "United Kingdom",
    "INSERM": "France",
    "IBM Laboratory": "Unknown",
    "the Netherlands": "Netherlands",
    "Dallas": "United States",
    "honda@nuee.nagoya-u.ac.jp": "Japan",
    "taly": "Italy",
    "South Korea": "South Korea",
    "State Key Laboratory of Structures": "China",
    "Berlin Institute of Technology": "Germany",
    "U.K,": "United Kingdom",
    "New Mexico": "United States",
    "Japan,": "Japan",
    "Freescale Semiconductors": "United States",
    "I-Shou Universíty": "Taiwan",
    "USA.": "United States",
    "NJ": "United States",
    "TX USA": "United States",
    "Japan": "Japan",
    "U.S.": "United States",
    "Reggio Calabria": "Italy",
    "NJ 07703 USA.": "United States",
    "Grenoble": "France",
    "TX 78712 USA": "United States",
    "National Chiao Tung University": "Taiwan",
    "yukari@jfcc.or.jp": "Japan",
    "Spain": "Spain",
    "Valencia": "Spain",
    "Fujitsu Semiconductor Ltd.": "Japan",
    "CS-ManTech IEEE Transactions on Semiconductor Manufacturing": "Unknown",
    "CL": "Chile",
    "Université de Toulouse": "France",
    "Inc.": "United States",
    "Greece": "Greece",
    "Tokyo Institute of Technology": "Japan",
    "Liechtenstein": "Liechtenstein",
    "Lithuania": "Lithuania",
    "Western University": "Canada",
    "HKUST Shenzhen Research Institute": "China",
    "Pakistan": "Pakistan",
    "Germay": "Germany",
    "Alaska": "United States",
    "Los Angeles": "United States",
    "Ludvika": "Sweden",
    "Republic ofKorea": "South Korea",
    "FL": "United States",
    "Department of Materials Science and Engineering": "Unknown",
    "WI": "United States",
    "AE": "United Arab Emirates",
    "Estonia": "Estonia",
    "University of Chinese Academy of Sciences": "China",
    "JP": "Japan",
    "DMCE GmbH": "Germany",
    "K2K 3G8 Canada": "Canada",
    "P R China": "China",
    "IN": "India",
    "University of Electronic Science and Technology of China": "China",
    "Syria": "Syria",
    "ISOM": "Unknown",
    "Albuquerque": "United States",
    "Uttarakhand": "India",
    "Malaysia": "Malaysia",
    "Macedonia": "North Macedonia",
    "FR": "France",
    "jan@seas.upenn.edu": "Unknown",
    "NJ 07666": "United States",
    "Qatar": "Qatar",
    "Ireland (e-mail: eoin.oreilly@tyndall.ie)": "Ireland",
    "Uzbekistan": "Uzbekistan",
    "CanadaCanada": "Canada",
    "amano@nuee.nagoya-u.ac.jp": "Japan",
    "639798": "Unknown",
    "Romania": "Romania",
    "Marseille": "France",
    "Jordan": "Jordan",
    "Linkoping": "Sweden",
    "Oak Ridge National Laboratory": "United States",
    "New Jersey": "United States",
    "s_anada@jfcc.or.jp": "Japan",
    "Uzbeksitan": "Uzbekistan",
    "TN": "United States",
    "Singapore": "Singapore",
    "University of Macau": "Macau",
    "U.S.A.": "United States",
    "Yugoslavia": "Serbia", 
    "UNRC/CONICET)": "Argentina",
    "P. R. China": "China",
    "NL": "Netherlands",
    "GA": "United States",
    "GLOBALFOUNDRIES Singapore Pte. Ltd": "Singapore",
    "Hong Kong": "Hong Kong",
    "ERI@N": "Japan",
    "JAPAN": "Japan",
    "University of Illinois": "United States",
    "LAPLACE": "France",
    "IE": "Ireland",
    "University of Glasgow": "United Kingdom",
    "Seattle": "United States",
    "Intel Labs": "United States",
    "CA 92182 USA": "United States",
    "Melaka": "Malaysia",
    "Taiwan R.O.C.": "Taiwan",
    "IEEE": "International",
    "SAR": "Saudi Arabia",
    "Malta": "Malta",
    "Morocco": "Morocco",
    "1South Korea": "South Korea",
    "Peru": "Peru",
    "Trinidad": "Unknown",
    "SE": "Unknown",
    "The Ohio State University": "United States",
    "Harbin": "China",
    "MA 02215 USA": "United States",
    "University of Illinois at Urbana-Champaign (UIUC)": "United States",
    "Micron Semiconductor Asia": "Singapore",
    "Moldova": "Moldova",
    "Nigeria": "Nigeria",
    "German": "Germany",
    "Federal University of Technology - Parana - UTFPR": "Brazil",
    "Cyprus": "Cyprus",
    "TX": "United States",
    "Zhuzhou": "China",
    "Sudan": "Sudan",
    "Institute of Electronics Engineering": "Unknown",
    "Wright-Patterson AFB": "United States",
    "MN": "United States",
    "AT": "Austria",
    "Madrid": "Spain",
    "Algérie": "Algeria",
    "Mexico": "Mexico",
    "S. Korea": "South Korea",
    "India. | U.K": "India",
    "U.K": "United Kingdom",
    "Korea Electrotechnology Research Institute": "South Korea",
    "Netherlands": "Netherlands",
    "639798 Singapore": "Singapore",
    "Australia and Australian Defence Science and Technology Organization": "Australia",
    "ROC": "Taiwan",
    "Cambridge": "United Kingdom",
    "U.S. Energy storage startup company": "United States",
    "Portugal": "Portugal",
    "San Pedro de Montes de Oca": "Costa Rica",
    "Neurelec company": "France",
    "Atlanta": "United States",
    "UK SW7 2A 7": "United Kingdom",
    "profumo@ucsc.edu": "Unknown",
    "Tyndall National Institute": "Ireland",
    "Intel Corporation": "United States",
    "ON Semiconductor": "United States",
    "R.O.C": "Taiwan",
    "k.olstein@ieee.org": "Unknown",
    "Republic of Tatarstan": "Russia",
    "East China University of Science and Technology": "China",
    "WA": "United States",
    "2016 CS MANTECH Technical Program Chair": "Unknown",
    "Nanyang Drive": "Singapore",
    "South Korea.": "South Korea",
    "Tianjin": "China",
    "TX 78735 USA": "United States",
    "Concepción": "Chile",
    "Yamaguchi University": "Japan",
    "Catania": "Italy",
    "GR": "Greece",
    "AL": "Albania",
    "AUC": "Egypt",
    "Indiana": "United States",
    "BE": "Belgium",
    "Universidad Tecnica Federico Santa Maria": "Chile",
    "Serbia": "Serbia",
    "k_nakano@jfcc.or.jp": "Japan",
    "Jhongli": "Taiwan",
    "E-mail: jannes.venter@up.ac.za": "South Africa",
    "INESC-ID": "Portugal",
    "Denton": "United Kingdom",
    "China": "China",
    "Advance Design Technology Inc.": "Unknown",
    "LA": "United States",
    "Rutherford Appleton Laboratory": "United Kingdom",
    "Harwell Oxford Didcot": "United Kingdom",
    "USA": "United States",
    "Ukraine": "Ukraine",
    "National Taiwan University": "Taiwan",
    "Kuwait": "Kuwait",
    "Proceedings of IEEE Society": "Unknown",
    "State College": "United States",
    "SJTU": "China",
    "UPS": "United States",
    "Wireless Systems Core Technology Department in the Wireless Advanced Technology Laboratory at Lucent Technologies in Whippany New Jersey": "United States",
    "sorinv@eecg.toronto.edu": "Canada",
    "Independent Consultant": "Unknown",
    "jim.brown@diasemi.com": "Unknown",
    "University of Michigan Dearborn": "United States",
    "Federal Republic of Germany": "Germany",
    "U.S. Department of the Navy": "United States",
    "Germany": "Germany",
    "Canada(CA)": "Canada",
    "ISAE": "France",
    "Iceland": "Iceland",
    "Viçosa": "Brazil",
    "University of Washington": "United States",
    "Republic of China": "Taiwan",
    "Leuven": "Belgium",
    "Tsukuba": "Japan",
    "Costa Rica": "Costa Rica",
    "Croatia": "Croatia",
    "Department of Information Technology (INTEC | Belarus": "Belarus",
    "TH": "Thailand",
    "VIC": "Australia",
    "GB": "United Kingdom",
    "College of Electronic Science and Engineering": "China",
    "Algeria": "Algeria",
    "U. K.": "United Kingdom",
    "and Research": "Unknown",
    "UAS": "United Arab Emirates",
    "China.": "China",
    "State University of New York at Binghamton": "United States",
    "Centre for THz Science and Engineering": "United Kingdom",
    "MD": "United States",
    "EG": "Egypt",
    "New Zealand": "New Zealand",
    "University of South Florida": "United States",
    "Austria": "Austria",
    "Sorbonne Universités": "France",
    "Jenin": "Palestine",
    "Türkiye": "Turkey",
    "PA": "United States",
    "Taiwan": "Taiwan",
    "Africa": "Africa",
    "Photonics Laboratories": "Unknown",
    "305-8577": "Unknown",
    "CONICET": "Argentina",
    "immunity and inflammation University of Glasgow": "United Kingdom",
    "sarita.thakoor@jpl.nasa.gov": "United States",
    "Latvia": "Latvia",
    "Egypt,": "Egypt",
    "Korea Advanced Institute of Science and Technology": "South Korea",
    "The Franklin Institute": "United States",
    "UT Austin": "United States",
    "Karnataka": "India",
    "Optoelectronics Laboratories of NTT": "Japan",
    "54th Research Institute of China Electronics Technology Group Corporation": "China",
    "Armenia": "Armenia",
    "Czechia": "Czech Republic",
    "Pacific Northwest National Laboratory": "United States",
    "E-mail: christo.versteeg@deneldynamics.co.za": "South Africa",
    "Chalmers University of Technology": "Sweden",
    "SG": "Singapore",
    "FI": "Finland",
    "Oulu University Hospital": "Finland",
    "Beijing": "China",
    "Process design group": "Unknown",
    "Northern Ireland": "United Kingdom",
    "tesla@ucsc.edu": "Unknown",
    "m_ogura@echo.nuee.nagoya-u.ac.jp": "Japan",
    "New York": "United States",
    "Tainan": "Taiwan",
    "Secure-IC S.A.S.": "France",
    "Amrrical Physical Society": "United States",
    "US": "United States",
    "École Polytechnique Fédérale de Lausanne": "Switzerland",
    "México": "Mexico",
    "DK": "Denmark",
    "JST PRESTO Researcher": "Japan",
    "AR 72701 USA": "United States",
    "University of Freiburg": "Germany",
    "Pacy-Sur-Eure": "France",
    "Carnegie Mellon University": "United States",
    "Lebanon": "Lebanon",
    "Brookhaven National Laboratory": "United States",
    "Consultant": "Unknown",
    "Boulder": "United States",
 "Italian Institute of Technology": "Italy",
 "R.O.C.": "Taiwan",
 "University of Sheffield": "United Kingdom",
 "University of Milano": "Italy",
 "UMR 1114 EMMAH (INRA-UAPV)": "France",
 "NXP Semiconductors": "Netherlands",
 "United Kingdom": "United Kingdom",
 "ECE": "Canada",
 "Saudi Arabia": "Saudi Arabia",
 "nomura.yuki001@jp.panasonic.com": "Japan",
 "Chile": "Chile",
 "Republic of Belarus": "Belarus",
 "Oman": "Oman",
 "Michigan Technological University": "United States",
 "Brazil": "Brazil",
 "Taiwan (R.O.C.)": "Taiwan",
 "University of Trento": "Italy",
 "Tampere University Hospital": "Finland",
 "SAR China": "China",
 "University of Michigan": "United States",
 "Chennai": "India",
 "Australia.": "Australia",
 "Scotland": "United Kingdom",
 "UAE": "United Arab Emirates",
 "CS MANTECH/IEEE Trans. Semiconductor Manufacturing": "Unknown",
 "Avezzano": "Italy",
 "TN 37996-2250 USA": "United States",
 "Berlin": "Germany",
 "a_tanaka@nuee.nagoya-u.ac.jp": "Japan",
 "CO": "Colombia",
 "Nederland": "Netherlands",
 "University of Duisburg-Essen": "Germany",
 "Manufacturing Technology Center": "Unknown",
 "Intel Corp.": "United States",
 "Broadway": "Unknown",
 "BR": "Brazil",
 "University of Toulouse": "France",
 "University of Missouri-Kansas City": "United States",
 "fauret@postino.up.ac.za": "South Africa",
 "Universitat Politècnica de Catalunya": "Spain",
 "Albert-Ludwigs-Universität": "Germany",
 "Switzerladn": "Switzerland",
 "Buddhist Tzu Chi General Hospital and Tzu Chi University": "Taiwan",
 "Venezuela": "Venezuela",
 "Nanjing": "China",
 "Tunisia": "Tunisia",
 "Electrical Engineering Department at Princeton University in New Jersey": "United States",
 "Raytbeodst Systems Corporation": "Unknown",
 "South Africa E-mail: Kharouna.Talla@nmmu.ac.za": "South Africa",
 "Hong Kong Polytechnic University": "Hong Kong",
 "CN": "China",
 "Yemen": "Yemen",
 "Institute for Electronics Engineering": "Unknown",
 "Ireland": "Ireland",
 "KS": "United States",
 "Orsay": "France",
 "Viet Nam": "Vietnam",
 "South Africa": "South Africa",
 "Kawasaki": "Japan",
 "Korea University": "South Korea",
 "University of Florida": "United States",
 "UK": "United Kingdom",
 "Canada.": "Canada",
 "AU": "Australia",
 "Trondheim": "Norway",
 "IBM Systems": "United States",
 "IBM Corporation": "United States",
 "Pusan National University Yangsan Hospital": "South Korea",
 "Noida": "India",
 "Chair of RF and Photonics Engineering": "Unknown",
 "Polytechnique Montreal": "Canada",
 "MY": "Malaysia",
 "France": "France",
 "Lakehead University": "Canada",
 "SouthAfrica (telephone: +27-21-808-4011": "South Africa",
 "Switzerland": "Switzerland",
 "University of Liverpool": "United Kingdom",
 "LT": "Lithuania",
 "Shizuoka University": "Japan",
 "PR China": "China",
 "Intel": "United States",
 "MilliLab and VTT Technical Research Centre of Finland": "Finland",
 "Korea Advanced Institute of Science and Technology (KAIST)": "South Korea",
 "United Arab Emirates": "United Arab Emirates",
 "Sweden": "Sweden",
 "DE": "Germany",
 "ES": "Spain",
 "United Emirates": "United Arab Emirates",
 "Indian Institute of Technology Kharagpur": "India",
 "Korea Telecom": "South Korea",
 "University of Virginia": "United States",
 "szornetzer@mail.arc.nasa.gov": "United States",
 "Changsha": "China",
 "Southern Methodist University": "United States",
 "Toshiba Corp.": "Japan",
 "Korea": "South Korea",
 "Bangladesh": "Bangladesh",
 "The Hong Kong University of Science and Technology": "Hong Kong",
 "South": "Unknown",
 "E-mail: monuko@up.ac.za": "South Africa",
 "CERN": "Unknown",
 "North China Electric Power University": "China",
 "Silicon": "Unknown",
 "Graduate School of Engineering Science and Technology": "Unknown",
 "Washington": "United States",
 "University of Salento": "Italy",
 "Cuba": "Cuba",
 "Nippon Telegraph and Telephone Corporation": "Japan",
 "3901 San Jose": "United States",
 "Philips Semiconductor": "Netherlands",
 "University of Tennessee": "United States",
 "Tehran": "Iran",
 "51 Hillbrook Drive": "United States",
 "Poland": "Poland",
 "Technical Program": "Unknown",
 "Agency of Science Technology and Research (A*STAR)": "Singapore",
 "The University of Surrey": "United Kingdom",
 "Russia": "Russia",
 "TW": "Taiwan",
 "Toyota Motor Corporation": "Japan",
 "CA 94720": "United States",
 "Ponta Grossa": "Brazil",
 "Egypt": "Egypt",
 "Chandler": "United States",
 "Belgium": "Belgium",
 "AR": "Argentina",
 "The Netherlands.": "Netherlands",
 "Ethiopia": "Ethiopia",
 "Kunming University of Science and Technology": "China",
 "United States": "United States",
 "India and": "India",
 "Haifa": "Israel",
 "NE": "United States",
 "University of Wollongong": "Australia",
 "Auckland Park Campus": "South Africa",
 "Brunei Darussalam": "Brunei",
 "Centre for Integrated Circuit Failure Analysis and Reliability": "Unknown",
 "Republic of Kazakhstan": "Kazakhstan",
 "Katholieke Universiteit": "Belgium",
 "Texas A&M University": "United States",
 "University of California": "United States",
 "Macao": "Macao",
 "Canada": "Canada",
 "University of Illinois at Urbana-Champaign": "United States",
 "Peregrine Semiconductor Co": "Unknown",
 "Optical Interconnection NEC Laboratory": "Japan",
 "Indonesia": "Indonesia",
 "Italia": "Italy",
 "Luxembourg": "Luxembourg",
 "CA 94035": "United States",
 "Corporation": "Unknown",
 "School of Information Science and Engineering and Shandong Provincial Key Laboratory of Laser Technology and Application": "China",
 "Karlsruhe Institute of Technology": "Germany",
 "N.Y.": "United States",
 "Nice-Sophia Antipolis University (TI chair of the Dream It foundation)": "France",
 "Colombia": "Colombia",
 "Stanford University": "United States",
 "MIND Microtechnologies": "Unknown",
 "CEA-LETI Minatec": "France",
 "Franc": "France",
 "The Republic of Korea": "South Korea",
 "Suwon": "South Korea",
 "CNRS": "France",
 "India": "India",
 "Fisk University": "United States",
 "Huawei": "China",
 "Korea1": "South Korea",
 "CAN": "Canada",
 "Borgaro Torinese": "Italy",
 "NC": "United States",
 "Portland State University": "United States",
 "k-yamamoto@jfcc.or.jp": "Japan",
 "Tajikistan": "Tajikistan",
 "University of Illinois at Urbana-Champaign (UiUC)": "United States",
 "CA": "United States",
 "Nice-Sophia Antipolis University": "France",
 "MA": "United States",
 "National Institute of Science and Technology on Semiconductor Nanodevices": "Unknown",
 "P.R.China": "China",
 "Hefei": "China",
 "yuuto_a@echo.nuee.nagoya-u.ac.jp": "Japan",
 "ccwang@ee.sysu.edu.tw": "Taiwan",
 "MStar Semiconductor Inc.": "Taiwan",
 "VA": "United States",
 "U.K.": "United Kingdom",
 "NY 13441": "United States",
 "Hyundai Motor Group": "South Korea",
 "2019 CS-MANTECH Conference Chair": "Unknown",
 "Pisa": "Italy",
 "MERL": "Unknown",
 "The Netherland": "Netherlands",
 "Samsung Electro Mechanics Company Limited": "South Korea",
 "MX": "Mexico",
 "Israel": "Israel",
 "Grenada": "Grenada",
 "Montana": "United States",
 "Vicky.Odendaal@deneldynamics.co.za": "South Africa",
 "LB": "Unknown",
 "National Cheng Kung University": "Taiwan",
 "Hong Kong SAR": "Hong Kong",
 "University of Ljubljana": "Slovenia",
 "Universidade Federal de Minas Gerais": "Brazil",
 "papoular@wanadoo.fr": "Unknown",
 "GRENOBLE": "France",
 "EM Microelectronic-Marin SA": "Switzerland",
 "2016 CS MANTECH General Chair": "Unknown",
 "ams Netherlands BV": "Netherlands",
 "Vietnam": "Vietnam",
 "South Africa E-mail: james.vd.vyver@deneldynamics.co.za": "South Africa",
 "Georgia": "Georgia",
 "United Technologies Research Center": "United States",
 "Nanyang Technological University": "Singapore",
 "Amherst": "United States",
 "OR": "United States",
 "The Institute of Scientific and Industrial Research Osaka University": "Japan",
 "IBM T.J. Watson Research Center": "Unknown",
 "State Key Laboratory on Fiber Optic Local Area Communication Networks and Advanced Optical Communication Systems": "China",
 "Florida": "United States",
 "Iran": "Iran",
 "Puerto Rico": "Puerto Rico",
 "Infineon Technologies Austria AG": "Austria",
 "Chinese Academy of Sciences": "China",
 "Hamburg": "Germany",
 "India~": "India",
 "Yamoussoukro": "Cote d'Ivoire",
 "NTT Optoelectronics": "Japan",
 "Douliou": "Taiwan",
 "Lisbon": "Portugal",
 "Semiconductor Power Electronics Center at North Carolina": "United States",
 "EC": "Unknown",
 "Hopewell Junction": "United States",
 "Taiwana": "Taiwan",
 "Turkey": "Turkey",
 "Chengdu": "China",
 "nagayoshi@heal.phy.saitama-u.ac.jp": "Japan",
 "Montenegro": "Montenegro",
 "Lawrence Berkeley National Laboratory": "United States",
 "Dow Chemicals": "United States",
 "Houston": "United States",
 "University of Montpellier": "France",
 "Zug": "Switzerland",
 "IRAQ": "Iraq",
 "Scotland U.K.": "United Kingdom",
 "Reinhardt.Botha@nmmu.ac.za": "South Africa",
 "NM": "United States",
 "US Army Electronics Command": "United States",
 "Iraq": "Iraq",
 "Osaka University": "Japan",
 "IL": "United States",
 "Australia": "Australia",
 "Taiwan R.O.C": "Taiwan",
 "Tokyo": "Japan",
 "Milan": "Italy",
 "University of Stuttgart": "Germany",
 "china": "China",
 "Fujitsu Laboratories Ltd.": "Japan",
 "RealTek Semiconductor Corporation": "Taiwan",
 "Taiwanese Defense Force": "Taiwan",
 "NCKU": "Taiwan",
 "Wuhan University of Technology": "China",
 "BITS Pilani Hyderabad campus": "India",
 "e-mail: hrgerber@sun.ac.za)": "South Africa",
 "Curitiba–PR–Brazil": "Brazil",
 "INDIA": "India",
 "Ithaca": "United States",
 "Japan.": "Japan",
 "Macau": "Macau",
 "University of Colorado School of Medicine": "United States",
 "Xylophone Optics": "United States",
 "Nippon Telegraph and Telephone": "Japan",
 "HK": "Hong Kong",
 "South Korea~": "South Korea",
 "Centro Federal de Educacao Tecnologica de Minas Gerais - CEFET/MG": "Brazil",
 "Arizona State University": "United States",
 "miko.matsumoto@furukawaelectric.com": "Japan",
 "Italy": "Italy",
 "Hittite Microwave Corporation": "United States",
 "Malaysia.": "Malaysia",
 "Norway": "Norway",
 "U.A.E.": "United Arab Emirates",
 "Dresden": "Germany",
 "Chin": "China",
 "Kazakhstan": "Kazakhstan",
 "PT": "Unknown",
 "Palestine": "Palestine",
 "KAIST": "South Korea",
 "kito.koji@starc.or.jp": "Japan",
 "Department of Electrical and Computer Engineering at the University of Illinois at Urbana-Champaign": "United States",
 "Republic of Korea": "South Korea",
 "Gujarat": "India",
 "School of Advanced Materials and Nanotechnology": "Unknown",
 "SUNY Binghamton": "United States",
 "University of Bergamo": "Italy",
 "Tampere University": "Finland",
 "Tianjin University": "China",
 "Department of Electrical Engineering": "Unknown",
 "Hungary": "Hungary",
 "Brasil": "Brazil",
 "CH": "Switzerland",
 "Finland": "Finland",
 "King Saud University": "Saudi Arabia",
 "Shanghai": "China",
 "Department of Electrical and Computer Engineering": "Unknown",
 "Portuga": "Portugal",
 "Lyngby": "Denmark",
 "Entegris": "United States",
 "Ireland eoin.oreilly@tyndall.ie": "Ireland"
}

# %%
with open('countrydict.json', "w") as json_file:
    json.dump(country_dict, json_file)
